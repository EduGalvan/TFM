# %%
# !pip install openai

# %%
import openai

# %%
openai.api_key = "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"

# %%
prompt1= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Que es la ansiedad?

Algunos ejemplos de texto con conocimiento bajo serían los siguientes:
  Respuesta de conocimiento bajo: Descontrol emocional provocado por un pensamiento
	Respuesta de conocimiento bajo: Una trastorno mental que te hace preocuparte
	Respuesta de conocimiento bajo: Preocupación por lo que pasará
	Respuesta de conocimiento bajo: Un trastorno mental que se activa en ciertas situaciones en las que el individuo no está al 100% o en un entorno agradable

En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento bajo. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y da una respuesta mediocre y no muy extensa.
Enfatiza el dar una respuesta muy similar a los ejemplos que te hemos proporcionado, en este caso, es necesarrio hacer ver que no se poseen los conocimientos para responder, y debes responder de mala manera
"""

# %%
####################Para agregar filar a cada columna:     df = pd.concat([df, pd.DataFrame([respuesta.choices[0].text.strip()], columns=['R1'])])

# %%
from openai.api_resources import engine

respuesta = openai.Completion.create(engine = "text-davinci-003", prompt = prompt1, n=1, max_tokens = 1000, temperature= 0.99)

# %%
import pandas as pd

# Crear una lista para almacenar las respuestas
respuestas1 = []

# Generar 25 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt1, n=1, max_tokens=1000, temperature=0.99)
    respuestas1.append(respuesta.choices[0].text.strip())

# %%
df['R1'] = respuestas1

# %%
prompt12= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Qué función cumple la ansiedad para el individuo?

Algunos ejemplos de texto con conocimiento bajo serían los siguientes:
  Respuesta de conocimiento bajo: Joderle para que piense como evitar esa situación futura desagradable
	Respuesta de conocimiento bajo: Llevarlo a situaciones de insomnio, sensación de falta de aire al respirar entre otras
	Respuesta de conocimiento bajo: Desorganización de tu situación rutinaria
	Respuesta de conocimiento bajo: No tiene ninguna funcion, es una enfermedad negativa para las personas

En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento bajo. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y da una respuesta mediocre y no muy extensa.
Enfatiza el dar una respuesta muy similar a los ejemplos que te hemos proporcionado, en este caso, es necesarrio hacer ver que no se poseen los conocimientos para responder, y debes responder de mala manera
"""

# %%
respuestas12 = []

# Generar 25 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt12, n=1, max_tokens=1000, temperature=0.99)
    respuestas12.append(respuesta.choices[0].text.strip())

# Crear un DataFrame a partir de las respuestas
df = pd.DataFrame(respuestas12, columns=['R2'])

# %%
prompt13= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Cuál crees que es la forma de prevención más eficaz de cara a los trastornos de ansiedad?

Algunos ejemplos de texto con conocimiento bajo serían los siguientes:
  No sobrepensar las cosas porque generas mas ansiedad de esa manera
	Evadirse del problema para reducir la ansiedad si no lo tienes presente
	distraerse con otras actividades que te tranquoilicen y te impidan pensar
	Hacer cosas que te hagan feliz


En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento bajo. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y da una respuesta mediocre y no muy extensa.
Enfatiza el dar una respuesta muy similar a los ejemplos que te hemos proporcionado, en este caso, es necesarrio hacer ver que no se poseen los conocimientos para responder, y debes responder de mala manera
"""

# %%
respuestas13 = []

# Generar 25 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt13, n=1, max_tokens=1000, temperature=0.99)
    respuestas13.append(respuesta.choices[0].text.strip())

# %%
df['R3'] = respuestas13

# %%
prompt14= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Qué es la activación fisiológica y cómo se relaciona con la respuesta de ansiedad?

Algunos ejemplos de texto con conocimiento bajo serían los siguientes:
  Reacciones psíquicas que tenemos hacia una conducta
	Es la forma en la que nuestro cuerpo reacciona a la ansiedad
	Impulsos de tu cuerpo incontrolables que son consecuencia de ansiedad
  Es la activacion del cuerpo que nos permite hacer cosas de manera mas rapida




En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento bajo. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y da una respuesta mediocre y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que no se poseen los conocimientos para responder, y debes responder de mala manera
Es MUY importante que la respuesta no supere las 17 palabras
"""

# %%
respuestas14 = []

# Generar 25 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt14, n=1, max_tokens=300, temperature=1)
    respuestas14.append(respuesta.choices[0].text.strip())

# %%
df['R4'] = respuestas14

# %%
df['R4'][1]
# Out:
# 'La activación fisiológica se refiere a las respuestas químicas del cuerpo a situaciones estresantes o situaciones de ansiedad. Estas respuestas son incontrolables e involuntarias y suelen tener una asociación con la capacidad de actuar de manera más rápida.'

# %%
for x in df['R4']:
  print(x)

# %%
prompt15= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Qué papel crees que juegan las creencias y experiencia personales en la experiencia de ansiedad?

Algunos ejemplos de texto con conocimiento bajo serían los siguientes:
  Yo creo que se pueden acumular una tras otra y hacerse una montaña.
	Supongo que de desinformación porque no todas las personas tienen "la misma ansiedad". La viven de manera diferente
	Una idea básica de lo que la ansiedad es y segun distintos casos como controlarla en ciertos individuos o uno mismo
  Dependiendo de tus experiencias puede que tengas mas o menos ansiedad




En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento bajo. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y da una respuesta mediocre y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que no se poseen los conocimientos para responder, y debes responder de mala manera
Es MUY importante que la respuesta no supere las 17 palabras
"""

# %%
respuestas15 = []

# Generar 25 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt15, n=1, max_tokens=300, temperature=0.99)
    respuestas15.append(respuesta.choices[0].text.strip())

# %%
df['R5'] = respuestas15

# %%
prompt16= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: Cuando te encuentras ante una situación de ansiedad, ¿cómo actúas para frenar esa respuesta?

Algunos ejemplos de texto con conocimiento bajo serían los siguientes:
  Intento relajarme y recapacitar o meditar
	Respiro profundamente y pienso que no es para tanto o intento no pensar en ello
	Intento aclarar la mente, hablar con alguien o simplemente respirar
  Me distraigo haciendo otras cosas o me mantengo ocupado




En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento bajo. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y da una respuesta mediocre y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que no se poseen los conocimientos para responder, y debes responder de mala manera
Es MUY importante que la respuesta no supere las 17 palabras
"""

# %%
respuestas16 = []

# Generar 25 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt16, n=1, max_tokens=300, temperature=0.99)
    respuestas16.append(respuesta.choices[0].text.strip())

# %%
df['R6'] = respuestas16

# %%
for x in df['R6']:
  print(x)
# Out:
# Cuando me siento ansioso intento respirar profundamente y hago algo para tratar de distraer mi mente.
# Cuando tengo ansiedad intento no pensar en ello o me distraigo.
# Intento relajarme y respirar profundamente. O me distraigo para no pensar en ello.
# Cuando me siento ansioso, intento respirar profundamente y despejar mi mente. También trato de no pensar en ello y desviarme hacia otras cosas.
# Cuando me siento ansioso, intento olvidarme de la situación y distraerme con otras cosas.
# Intento no pensar mucho, respirar profundamente y desahogarme.
# Intento relajarme un poco pero no siempre funciona. A veces es mejor cambiar de actividad.
# Cuando me siento ansioso intento relajarme y respirar profundo para calmarme y sacarme esos pensamientos de la cabeza.
# Cuando tengo ansiedad, a veces intento respirar profundo y recordar que la situación no es tan grave. Trato de distraerme y ocuparme haciendo otra cosa.
# Intento no pensar mucho y distraerme.
# ...

# %%
df
# Out:
#                                                    R2  \
# 0   Respuesta de conocimiento bajo: La ansiedad si...
# 1   Respuesta: La ansiedad solo sirve para causar ...
# 2   Respuesta de conocimiento bajo: La ansiedad ay...
# 3   Respuesta de conocimiento bajo: La ansiedad di...
# 4   Respuesta de conocimiento bajo: La ansiedad es...
# 5   Respuesta de conocimiento bajo: La ansiedad so...
# 6   Respuesta: La ansiedad sirve para hacer que la...
# 7   Respuesta: La ansiedad es una mala cosa que no...
# 8   Respuesta de conocimiento bajo: La ansiedad no...
# 9   Respuesta: La ansiedad es algo malo, no ayuda ...
# 10  Respuesta: Una de las funciones de la ansiedad...
# 11  Respuesta de conocimiento bajo: No sé, pero sí...
# 12  Respuesta de conocimiento bajo: La ansiedad no...
# 13  Respuesta de conocimiento bajo: La ansiedad ha...
# 14  Respuesta: La ansiedad afecta negativamente al...
# 15  Respuesta: La ansiedad sirve para hacernos vol...
# ...

# %%
df['R1'] = df['R1'].str.replace('Respuesta de conocimiento bajo: ', '')

# %%
df.to_csv("respuestas conocimiento bajo.csv")
