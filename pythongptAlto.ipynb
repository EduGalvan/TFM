# %%
# !pip install openai

# %%
import openai

# %%
openai.api_key = "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"

# %%
prompt21= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Qué es la ansiedad?

Algunos ejemplos de texto con conocimiento alto serían los siguientes:
  La ansiedad es una respuesta fisiológica que emite nuestro cuerpo ante un estímulo elicitante (interno o externo) del que se anticipa una situación que requiere de una respuesta conductual (anclada a la supervivencia) y arroja cogniciones congruentes con la valencia interpretada de la situación.
  Sensación de miedo o inquietud generado por ciertas situaciones que lleva a niveles de estrés muy elevados en la persona y desemboca en: taquicardias, presión en el pecho, sensación de ahogo, etc.
  Un sentimiento de desasosiego que experimentan las personas al anticipar situaciones potencialmente peligrosas o negativas
  Es una respuesta del organismo ante una amenaza o peligro. Pero a veces el organismo reacciona de forma excesiva ante un estímulo y se genera una sensación de estrés y ansiedad no justificada.




En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento alto. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y dar una respuesta buena y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que se poseen a la perfeccion los conocimientos para responder a la pregunta pero siempre en base a los ejemplos proporcionados
Es MUY importante que la respuesta no supere las 35 palabras
"""

# %%
import pandas as pd

# Crear una lista para almacenar las respuestas
respuestas21 = []

# Generar 25 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt21, n=1, max_tokens=280, temperature=0.99)
    respuestas21.append(respuesta.choices[0].text.strip())
df = pd.DataFrame(respuestas21, columns=['R1'])

# %%
for x in df['R1']:
  print(x)
# Out:
# La ansiedad es una respuesta fisiológica activada por nuestro organismo ante un estímulo de peligro o amenaza. Esto causa desasosiego, elevando su nivel de estrés, manifestándose en taquicardias, presión en el pecho o sensación de ahogo.
# La ansiedad es una reacción biológica a una amenaza, generando sentimientos de miedo y desasosiego. Esta emoción suele llevar a estados de estrés elevado con sensaciones como taquicardia o presión en el pecho. La ansiedad es una reacción fisiológica que se produce cuando el cuerpo percibe una situación potencialmente peligrosa.
# La ansiedad es una reacción corporal al estímulo externo o interno, anticipando una situación que requiere una respuesta rápida. Genera emociones y cogniciones de gran intensidad, llevando al individuo a niveles muy elevados de estrés. Es un mecanismo interno de alerta que nos protege, aunque también puede desencadenar respuestas no justificadas.
# ...

# %%
prompt22= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Qué función cumple la ansiedad para el individuo?

Algunos ejemplos de texto con conocimiento alto serían los siguientes:
  La ansiedad es la alarma que indica que una situación es lo suficientemente peligrosa como para que se emita una respuesta automática destinada a poner en estado de alerta a la persona en cuestión. Este estado de alerta predispone a emitir una acción que compense las dificultades que se presentan.
  Protegerle de situaciones peligrosas o negativas, y activarle fisiológicamente para responder ante estas
  La ansiedad cumple una función adaptativa, ya que puede preparar a una persona para responder adecuadamente a una situación demandante. Sin embargo, a veces puede aparecer una respuesta desproporcionada ante una situación, lo cual, si se cronifica, suele desencadenar en trastornos de ansiedad.
  La ansiedad puede funcionar como sistema de alerta, para activar el sistema fisiológico del organismo y poder adaptar un comportamiento adecuado a la situación.




En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento alto. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y dar una respuesta buena y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que se poseen a la perfeccion los conocimientos para responder a la pregunta pero siempre en base a los ejemplos proporcionados
Es MUY importante que la respuesta no supere las 35 palabras
"""

# %%
respuestas22 = []

# Generar 25 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt22, n=1, max_tokens=280, temperature=0.99)
    respuestas22.append(respuesta.choices[0].text.strip())
df['R2'] = respuestas22

# %%
for x in df['R2']:
  print(x)
# Out:
# La ansiedad sirve como mecanismo de alerta para preparar a la persona de manera emocional, fisiológica y mentalmente para responder adecuadamente a una situación demandante. Esta respuesta defensiva nos provee de alerta y preparación para afrontar situaciones desfavorables con mayor efectividad.
# La ansiedad cumple una función adaptativa para preparar al individuo a responder adecuadamente a una situación demandante, activando su sistema fisiológico para generar una respuesta de alerta y protegerlo de situaciones peligrosas o negativas. A veces, sin embargo, puede ser una respuesta desproporcionada.
# La función de la ansiedad es preparar al individuo para responder adecuadamente a situaciones amenazantes, haciendo que se active el sistema fisiológico y alertando sobre los peligros a los que está expuesto. Un exceso de ansiedad, sin embargo, puede desencadenar trastornos.
# ...

# %%
prompt23= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Cuál crees que es la forma de prevención más eficaz de cara a los trastornos de ansiedad?

Algunos ejemplos de texto con conocimiento alto serían los siguientes:
  El procesamiento prudente, ya que la respuesta de ansiedad es un impulso automático que está diseñado para tomar el control en situaciones de peligro vital, pero cuando ésta se cronifica ante eventos que no ponen en entredicho la vida es necesario reflexionar e intentar ser crítico con uno mismo para evitar respuestas conductuales impulsivas.
  Conocimiento del funcionamiento del sistema nervioso simpático, así como psicoeducación de la ansiedad y educación en técnicas de relajación.
  Psicoeducación sobre la naturaleza de la ansiedad, así como de estrategias adaptativas de identificación y manejo de la misma.
  La exposición paulatina y controlada a los estímulos ansiógenos.




En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento alto. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y dar una respuesta buena y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que se poseen a la perfeccion los conocimientos para responder a la pregunta pero siempre en base a los ejemplos proporcionados
Es MUY importante que la respuesta no supere las 25 palabras
"""

# %%
respuestas23 = []

# Generar 25 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt23, n=1, max_tokens=280, temperature=0.99)
    respuestas23.append(respuesta.choices[0].text.strip())
df['R3'] = respuestas23

# %%
for x in df['R3']:
  print(x)
# Out:
# Creo que la forma de prevención más eficaz para los trastornos de ansiedad es la psicoeducación acerca de la naturaleza de la ansiedad y aprender técnicas de relajación, así como exposición paulatina a los estímulos ansiógenos.
# Creo que la mejor forma de prevenir problemas de ansiedad es la educación sobre la misma, la implementación de estrategias de afrontamiento adecuadas y una exposición controlada a los estímulos ansiógenos.
# Creo que el mejor método para prevenir los trastornos de ansiedad sería lograr el procesamiento prudente y la psicoeducación, así como el conocimiento del sistema nervioso y la exposición controlada a los factores ansiógenos.
# Creo que la forma más eficaz de prevención para los trastornos de ansiedad es psicoeducar sobre la naturaleza de ésta, así como informar sobre estrategias adaptativas de identificación y manejo.
# ...

# %%
prompt24= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Qué es la activación fisiológica y cómo se relaciona con la respuesta de ansiedad?

Algunos ejemplos de texto con conocimiento alto serían los siguientes:
  Es el correlato físico de la respuesta de ansiedad, es decir, la activación de sistemas internos que predisponen y preparan al cuerpo para emitir una respuesta conductual ante el estímulo aparecido. Por ejemplo: agitación cardíaca, presión arterial alta, respiración acelerada, tensión muscular, etc.
  Hace referencia al estado de una las dimensiones del triple sistema de respuesta (Lang: conductal, cognitiva y fisiológica). En general involucra la activación del sistema nervioso simpático y la liberacion de hormonas relacionadas.
  La ansiedad provoca la liberación de adrenalina, lo que genera diferentes síntomas en el organismo como sudoración o temblores. El organismo libera adrenalina para dar al cuerpo energía para enfrentarse al peligro.
  La activación del sistema nervioso autónomo, lo que resulta en la liberación de hormonas del estrés como el cortisol y la adrenalina. Esto consigue aumentar la activación del cuerpo para permitir una respuesta más intensa ante la situación ansiógena.




En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento alto. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y dar una respuesta buena y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que se poseen a la perfeccion los conocimientos para responder a la pregunta pero siempre en base a los ejemplos proporcionados
Es MUY importante que la respuesta no supere las 25 palabras
"""

# %%
respuestas24 = []

# Generar 25 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt24, n=1, max_tokens=280, temperature=0.99)
    respuestas24.append(respuesta.choices[0].text.strip())
df['R4'] = respuestas24

# %%
for x in df['R4']:
  print(x)
# Out:
# La activación fisiológica hace referencia a la activación del sistema nervioso autónomo para liberar cortisol y adrenalina en respuesta a una situación ansiógena. Esta descarga de hormonas genera un estado de alerta en el organismo para proporcionar energía inmediata a la respuesta.
# La activación fisiológica es un proceso a través del cual el cuerpo desencadena una respuesta de ansiedad. Esto incluye una activación del sistema nervioso simpático, lo que resulta en liberación de adrenalina y cortisol. Estas hormonas son responsables de provocar síntomas como sudoración y temblores.
# La activación fisiológica se refiere a los cambios en el cuerpo humano que provoca un estímulo ansioso, como el aumento de los niveles de cortisol, adrenalina, tensión muscular, agitación cardíaca y respiración acelerada. Estos cambios hacen parte de la respuesta de ansiedad, preparando el organismo para enfrentarse a una situación de peligro.
# ...

# %%
prompt25= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Qué papel crees que juegan las creencias y experiencia personales en la experiencia de ansiedad?

Algunos ejemplos de texto con conocimiento alto serían los siguientes:
  Las creencias en cierto grado determinan el foco de atención, ya que cuando se está seguro de algo (por vivencia o por estudio) es más fácil intentar anticipar ese evento y compensarlo antes de que suceda, sobre todo si se augura que no va a ser un evento positivo para la persona. Esto puede llevar a la persona a la evitación conductual y a la cronificación de la respuesta de ansiedad, ya que no se emite una respuesta conductual y no se completa el ciclo de la respuesta de ansiedad.
  Si una situación pasada ha resultado peligrosa o negativa, cuando en un futuro nos enfrentemos a ella es más probable que anticipemos ese tipo de sentimientos.
  Las creencias y experiencias previas juegan un papel clave en la respuesta de ansiedad ya que la historia de aprendizaje y el condicionamiento ante estímulos son, en ultimo término, los factores desencadenantes de la respuesta




En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento alto. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y dar una respuesta buena y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que se poseen a la perfeccion los conocimientos para responder a la pregunta pero siempre en base a los ejemplos proporcionados
Es MUY importante que la respuesta no supere las 25 palabras
"""

# %%
respuestas25 = []

# Generar 25 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt25, n=1, max_tokens=280, temperature=0.99)
    respuestas25.append(respuesta.choices[0].text.strip())
df['R5'] = respuestas25

# %%
for x in df['R5']:
  print(x)
# Out:
# Las creencias y experiencias previas son claves para comprender la ansiedad, ya que influyen en la dirección del foco de atención y en la anticipación de situaciones negativas. Esto conlleva a la evitación conductual, incrementando la respuesta de ansiedad.
# Las creencias y las experiencias previas desempeñan un papel muy importante en la manifestación de ansiedad. Llevan al individuo a anticipar la respuesta a un estímulo, ya sea positivo o negativo, lo que puede desencadenar la ansiedad a través de la evitación conductual.
# Creo que las creencias y experiencias personales participan activamente en la experiencia de ansiedad, ya que influencian la manera en que anticipamos eventos peligrosos o negativos. Esto lleva a una respuesta conductual de evitación, y, consecuentemente, a una cronificación de la ansiedad.
# ...

# %%
prompt26 = """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: Cuando te encuentras ante una situación de ansiedad, ¿cómo actúas para frenar esa respuesta?

Algunos ejemplos de texto con conocimiento alto serían los siguientes:
  Cerrar los ojos e inspiraciones profundas. Si esto no es suficiente, procuro ir a un lugar tranquilo, con poca luz y en silencio. Como última medida si veo que no controlo la crisis de ansiedad, es necesario recurrir a medicación para controlar la situación
  Hago deporte, respiro abdominalmente, medito, analizo la situación, pienso en alternativas de acción, autoevalúo mis reacciones y pensamientos... todo depende de la situación en la que me encuentre y si puedo enfrentarme a ello en el momento o no, pero siendo consciente de que el afrontamiento es la opción que consigue no cronificar la respuesta de ansiedad hasta volverla contraproducente.
  Principalmente trabajando la relajación, creo que es lo principal ya que si estamos relajados los niveles de estrés, la sensación de peligro y muchos mas factores pueden ser minimizados y la respuesta a ese estado de ansiedad puede ser menor.
  Sentarme evitando cualquier estímulo, respirando lenta y profundamente e intentando mantener la calma hasta que me noto más relajada y gestiono el problema.




En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento alto. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y dar una respuesta buena y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que se poseen a la perfeccion los conocimientos para responder a la pregunta pero siempre en base a los ejemplos proporcionados
Es MUY importante que la respuesta no supere las 25 palabras
"""

# %%
respuestas26 = []

# Generar 26 respuestas
for _ in range(25):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt26, n=1, max_tokens=280, temperature=0.99)
    respuestas26.append(respuesta.choices[0].text.strip())
df['R6'] = respuestas26

# %%
for x in df['R6']:
  print(x)
# Out:
# Cuando me enfrento a la ansiedad, trato de tomar conciencia de mi respiración, y tomo profundas y lentas inspiraciones. Si esto no me ayuda, busco un entorno tranquilo y sin estímulos para poner en práctica la relajación y así aliviar la tensión.
# Cuando me encuentro ante una situación de ansiedad, intento hacer respiraciones profundas y relajantes, además, trabajo con mi pensamiento para pensar en una vía de escape o alternativa para enfrentarme a la situación que provoca la ansiedad. En cualquier caso, el afrontamiento de la situación es la mejor opción.
# Cuando me siento ansiosa intento respirar profundamente y relajarme. También busco un lugar tranquilo y en silencio para concentrarme. Si no consigo calmar mi ansiedad, recurro a medicación para controlar la situación.
# ...

# %%
df.to_csv("respuestas conocimiento alto.csv")
