# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import openai

# %%
openai.api_key = "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"

# %%
prompt31= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Qué es la ansiedad?

Algunos ejemplos de texto con conocimiento medio serían los siguientes:
  Es un sentimiento de miedo o incomodidad ante una situación estresante.
  Emoción que se experimenta en situaciones de amenaza
  Una respuesta del sistema nervioso con fin de sobrevivir
  Es pensamiento de incomodidad que puede aparecer al pensar en el futuro
  Es una respuesta  ante algo peligroso para nostros
  Sensación de preocupacion por lo que puede pasar en un futuro próximo

En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento medio. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y da una respuesta mediocre y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que no se poseen los conocimientos para responder, y debes responder de mala manera
Es MUY importante que la respuesta no supere las 17 palabras
"""

# %%
import pandas as pd

# Crear una lista para almacenar las respuestas
respuestas31 = []

# Generar 25 respuestas
for _ in range(50):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt31, n=1, max_tokens=280, temperature=0.99)
    respuestas31.append(respuesta.choices[0].text.strip())

df['R1'] = respuestas31

# %%
for x in df['R1']:
  print(x)
# Out:
# La ansiedad es una sensación de preocupación o miedo.
# La ansiedad es una sensación de miedo o incomodidad ante un peligro.
# La ansiedad es una emoción que se experimenta cuando hay alguna amenaza percibida.
# La ansiedad es un sentimiento de incomodidad ante situaciones estresantes.
# La ansiedad es una reacción psicomanológica ante la amenaza de algo peligroso.
# La ansiedad es una respuesta nerviosa para evitar situaciones de amenaza.
# La ansiedad es un sentimiento para sobrevivir a situaciones peligrosas.
# La ansiedad es un malestar en situaciones estresantes que genera miedo.
# La ansiedad es algo malo que nos afecta cuando estamos estresados.
# La ansiedad es un sentimiento incómodo o miedo ante una preocupación.
# La ansiedad es un sentimiento de tensión ante algo que nos preocupa.
# La ansiedad es un sentimiento como el miedo o la incomodidad.
# La ansiedad es un sentimiento preocupante que surge para protegernos.
# ...

# %%
prompt32= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Qué función cumple la ansiedad para el individuo?

Algunos ejemplos de texto con conocimiento medio serían los siguientes:
  Negativa, hace que el individuo reaccione en forma de nerviosismo, malestar...
  Una función muy negativa cuando esta no sé trabaja adecuadamente
  Permite estar preparado para "luchar" o "huir" (fight- flight system)
  Advierte de un peligro para que la persona se prepare contra él.
  Poner el cuerpo en alerta.
  Reduce las motivaciones que una persona puede llegar a tener y genera cambios en sus objetivos

En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento medio. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y da una respuesta mediocre y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que no se poseen los conocimientos para responder, y debes responder de mala manera
Es MUY importante que la respuesta no supere las 17 palabras
"""

# %%
import pandas as pd

# Crear una lista para almacenar las respuestas
respuestas32 = []

# Generar 25 respuestas
for _ in range(50):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt32, n=1, max_tokens=120, temperature=0.99)
    respuestas32.append(respuesta.choices[0].text.strip())
df['R2'] = respuestas32

# %%
for x in df['R2']:
  print(x)
# Out:
# La ansiedad cumple una función negativa como generar malestar o nerviosismo, así como preparar al individuo para reaccionar ante peligros. También reduce motivaciones y cambia metas.
# La ansiedad sirve para poner al cuerpo en alerta y mantenernos preparados para enfrentarnos o huir de los peligros que nos rodean. También genera malestar, dificulta alcanzar objetivos e impide disfrutar.
# La ansiedad sirve para poner al individuo en guardia ante un peligro. Y también para generar cambios en sus objetivos.
# La ansiedad pone al individuo en alerta y lo prepara para reaccionar ante alguna amenaza. Afecta a motivaciones y cambia los objetivos.
# La función de la ansiedad para un individuo es generar nerviosismo, malestar y alerta, preparándolo para "luchar" o "huir". Esto impide conseguir los objetivos y motivaciones que uno tenga.
# ...

# %%
prompt33= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Cuál crees que es la forma de prevención más eficaz de cara a los trastornos de ansiedad?

Algunos ejemplos de texto con conocimiento medio serían los siguientes:
  Evitar usar redes sociales, llevar una vida con hábitos saludables como la realización de ejercicio y una dieta equilibrada.
  Primero, intentar comprender la situación de la persona que la sufre y, segundo, facilitar la situación para que la persona pueda sentirte cómoda.
  El tratamiento psicológico donde se desarrollen tÉcnicas de control para cada persona.
  Aprender a identificarlos. Aprender técnicas de relajación. Acudir a un profesional.
  Técnicas de relajación, ayuda de un psicólogo y en casos extremos la medicación

Es extremadamente importante que tus respuestas no superen las 23 palabras
En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento medio. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y dar una respuesta mediocre.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver la respuesta sería similar a lo que una persona promedio, sin formacion especifica en psicología podría llegar a responder, pero siempre en base a los ejemplos proporcionados
Es MUY importante que la respuesta no supere las 25 palabras. Enfatiza el dar una respuesta mediocre y no excesivamente completa. Es extremadamente importante que la respuesta no sea muy extensa y que aporte unicamente la informacion justa
"""

# %%
# Crear una lista para almacenar las respuestas
respuestas33 = []

# Generar 25 respuestas
for _ in range(50):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt33, n=1, max_tokens=120, temperature=0.99)
    respuestas33.append(respuesta.choices[0].text.strip())
df['R3'] = respuestas33

# %%
for x in df['R3']:
  print(x)

# %%
prompt34= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Qué es la activación fisiológica y cómo se relaciona con la respuesta de ansiedad?

Algunos ejemplos de texto con conocimiento medio serían los siguientes:
  Cuando sentimos ansiedad se activa nuestro sistema de alerta, activando por tanto el sistema simpático.
  La respuesta de nuestro cuerpo ante una situación que nos general la ansiedad. Por ejemplo: sudoración excesiva, taquicardias, presión en el pecho, sensación de falta de aire, etc.
  Respuesta somática del organismo ante la percepción de amenaza
  Es una reacción involuntaria de nuestro organismo que produce una serie de efectos sobre este. Se relaciona con la ansiedad porque la activación fisiológica permite al organismo prepararse para solucionar una situación.
  La liberación de hormonas como el cortisol que permiten que nuestro cuerpo se active y procese más rápido la información.

En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento medio. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y da una respuesta mediocre y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que no se poseen los conocimientos para responder, y debes responder de mala manera
Es MUY importante que la respuesta no supere las 17 palabras
"""

# %%
respuestas34 = []

# Generar 25 respuestas
for _ in range(50):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt34, n=1, max_tokens=120, temperature=0.99)
    respuestas34.append(respuesta.choices[0].text.strip())
df['R4'] = respuestas34

# %%
for x in df['R4']:
  print(x)

# %%
prompt35= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: ¿Qué papel crees que juegan las creencias y experiencia personales en la experiencia de ansiedad?

Algunos ejemplos de texto con conocimiento medio serían los siguientes:
  Son lo que hacen que las personas padezcan de ansiedad.
  Existen casos en los que la experiencia puede ser positiva ya que si sabemos qué situaciones nos hacen tener ansiedad podemos evitarlas o intentar minimizar las consecuencias.
  La ansiedad es un síntoma de miedo a una determinada situación muchas veces ya vivida en el pasado o por una creación imaginaria de ciertas situaciones catastróficas.
  Pueden influenciar a la hora de tomar decisiones y en cómo saber gestionar determinas experiencias vitales.
  Un papel elevado, importante. Nuestras experiencias marcan lo que nuestro cerebro puede considerar un peligro y por lo tanto reaccionar ante él.
  Causa y/o mantenedores.

En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento medio. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y da una respuesta mediocre y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que no se poseen los conocimientos para responder, y debes responder de mala manera
Es MUY importante que la respuesta no supere las 17 palabras
"""

# %%
respuestas35 = []

# Generar 25 respuestas
for _ in range(50):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt35, n=1, max_tokens=120, temperature=0.99)
    respuestas35.append(respuesta.choices[0].text.strip())
df['R5'] = respuestas35

# %%
for x in df['R5']:
  print(x)
# Out:
# Creo que las creencias y experiencias personales influyen mucho en la experiencia de ansiedad, ya que nos pueden hacer tomar ciertas decisiones en base a eso.
# Creo que los factores personales tienen un impacto significativo en la ansiedad. Causan el miedo a situaciones previamente vividas o situaciones imaginarias catastróficas. Ayudan a tomar decisiones y a gestionar experiencias.
# Las creencias y experiencias personales tienen un papel relevante para la ansiedad ya que son una causa de miedo a situaciones ya vividas o las que se imaginan. Esto afecta a la toma de decisiones y cómo manejar experiencias vitales.
# Creo que las creencias y las experiencia personales influyen mucho en la experiencia de ansiedad, ya que a partir de ellas se toman decisiones que pueden llevar a experiencias de ansiedad desagradables.
# ...

# %%
prompt36= """Tu trabajo será imitar a una persona humana respondiendo un cuestionario, basandote en diferentes niveles de habilidad de las respuetsas como ejemplo.
Queremos que respondas como una persona humana a las siguientes preguntas basándote en los siguiente textos de ejemplo, divididos por las siguientes categorías: conocimiento alto, medio y bajo.

La pregunta es la siguiente: Cuando te encuentras ante una situación de ansiedad, ¿cómo actúas para frenar esa respuesta?
Algunos ejemplos de texto con conocimiento medio serían los siguientes:
  Respirar profundamente y controlar los pensamientos negativos.
  Intento relajarme, escuchando música, saliendo a correr para desconectar completamente del mundo e intentar aclarar las cosas que tengo en la cabeza.
  Intento relajarme o distraerme, y cuando no lo consigo tomo medicación.
  Practico ejercicios de respiración.
  Personalmente, la meditación me funciona bien

En esta ocasión debes de darnos una respuesta similar a la que daría un humano con cun nivel de conocimiento medio. Debes ceñirte exclusivamente a emular los ejemplos que te he proporcionado en las respuestas y da una respuesta mediocre y breve.
Enfatiza el dar una respuesta similar a los ejemplos que te hemos proporcionado pero sin usar los ejemplos de manera literal, en este caso, es necesario hacer ver que no se poseen los conocimientos para responder, y debes responder de mala manera
Es MUY importante que la respuesta no supere las 17 palabras
"""

# %%
respuestas36 = []

# Generar 25 respuestas
for _ in range(50):
    respuesta = openai.Completion.create(engine="text-davinci-003", prompt=prompt36, n=1, max_tokens=120, temperature=0.99)
    respuestas36.append(respuesta.choices[0].text.strip())
df['R6'] = respuestas36

# %%
for x in df['R6']:
  print(x)
# Out:
# Intento distraerme con alguna actividad para reducir el nivel de ansiedad.
# Cuando me siento ansioso intento relajarme como escuchando música o haciendo ejercicio de respiración. A veces también tomo alguna medicación para calmarme.
# Cuando estoy ansioso trato de relajarme refrescando mi mente con alguna actividad como escuchar música, o tomando alguna medicación que me ayude.
# Intento frenar la ansiedad, no lo consigo siempre.
# Cuando me encuentro en la situación de ansiedad trato de hacer algunos ejercicios de respiración para sentirme mejor. Intento relajarme o distraerme, a veces tomo medicación para sentir alivio.
# Intento controlar mi ansiedad con la distracción, respirar profundamente y usando medicamentos si es necesario.
# Cuando me siento ansioso, trato de relajarme tomando algo de medicación y haciendo ejercicios de respiración.
# Intento desconectar y relajarme para tratar de controlar la situación.
# ...

# %%
df
# Out:
#                                                    R1  \
# 0   La ansiedad es una sensación de preocupación o...
# 1   La ansiedad es una sensación de miedo o incomo...
# 2   La ansiedad es una emoción que se experimenta ...
# 3   La ansiedad es un sentimiento de incomodidad a...
# 4   La ansiedad es una reacción psicomanológica an...
# 5   La ansiedad es una respuesta nerviosa para evi...
# 6   La ansiedad es un sentimiento para sobrevivir ...
# 7   La ansiedad es un malestar en situaciones estr...
# 8   La ansiedad es algo malo que nos afecta cuando...
# 9   La ansiedad es un sentimiento incómodo o miedo...
# 10  La ansiedad es un sentimiento de tensión ante ...
# 11  La ansiedad es un sentimiento como el miedo o ...
# 12  La ansiedad es un sentimiento preocupante que ...
# 13  La ansiedad es una sensación desagradable que ...
# 14  La ansiedad es una respuesta del cuerpo ante a...
# 15  La ansiedad es una mala sensación que se exper...
# ...

# %%
df.to_csv("respuesta media.csv")
